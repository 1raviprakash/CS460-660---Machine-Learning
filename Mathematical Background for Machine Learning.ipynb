# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # A

# %%
m = [0, 0]
C_M = [[1, 0], [0, 1]]

x, y = np.random.multivariate_normal(m, C_M, 100).T
plt.plot(x, y, 'o')
plt.show()

# %% [markdown]
# # B

# %%
m=[-1,1]
x,y=np.random.multivariate_normal(m,C_M,100).T
plt.plot(x, y, 'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # C

# %%
m=[0,0]
C_M=[[2,0], [0,2]]

x,y=np.random.multivariate_normal(m,C_M,100).T
plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# # D

# %%
m=[0,0]
C_M=[[1,0.5], [0.5,1]]
x,y=np.random.multivariate_normal(m,C_M,100).T
plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# # E

# %%
m=[0,0]
C_M=[[1,-0.5], [-0.5,1]]
x,y=np.random.multivariate_normal(m,C_M,100).T
plt.plot(x,y,'o')
plt.show()
